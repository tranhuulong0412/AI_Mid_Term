# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/AI/FaceMembersOfClass/
# Out:
# /content/drive/MyDrive/AI/FaceMembersOfClass

# %%
#Import các thư viện liên quan cần sử dụng
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#Thư viện tạo mô hình CNN
from keras import models
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Normalization, Dropout
from keras.layers import LeakyReLU

from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import to_categorical # one hot encoding

#Thư viện vẽ đồ thị
from matplotlib import pyplot as plt 

from sklearn import preprocessing
from tensorflow.keras.models import load_model
from keras.utils import load_img
from keras.utils.image_utils import img_to_array
import os
import numpy as np

train_datagen=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
# Tạo bộ dữ liệu chứa dữ liệu dùng để training
training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/AI/FaceMembersOfClass/Train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 372 images belonging to 7 classes.

# %%
# Lấy ra tên của từng thư mục chứa từng loại dữ liệu
training_set.class_indices
# Out:
# {'HoaiPhong': 0,
#  'HongMinh': 1,
#  'HuuLong': 2,
#  'QuangHuy': 3,
#  'TrongLuan': 4,
#  'TrungHau': 5,
#  'VietHa': 6}

# %%
#Define và compile CNN model
model=Sequential()

# Nhân tích chập 32 lần
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) 
#Hàm loại bỏ
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D(2,2))
# Nhân tích chập 64 lần 
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
#Hàm loại bỏ
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D(2,2))
# Nhân tích chập 128 lần 
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
#Hàm loại bỏ
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D(2,2))

model.add(Flatten())

model.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
model.add(Dense(7,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  leaky_re_lu (LeakyReLU)     (None, 150, 150, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 75, 75, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 37, 37, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 256)               10617088
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 10,712,135
# Trainable params: 10,712,135
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Complie mô hình CNN
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
#Lưu lại giá trị mỗi lần học để vẽ ra đồ thị
history=model.fit(training_set,epochs=30,batch_size=128,verbose=1)
# Out:
# Epoch 1/30
# 12/12 [==============================] - 81s 6s/step - loss: 12.3092 - accuracy: 0.2312
# Epoch 2/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.5699 - accuracy: 0.8522
# Epoch 3/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.2058 - accuracy: 0.9435
# Epoch 4/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.0603 - accuracy: 0.9812
# Epoch 5/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.0309 - accuracy: 0.9919
# Epoch 6/30
# 12/12 [==============================] - 29s 2s/step - loss: 0.0410 - accuracy: 0.9866
# Epoch 7/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.0543 - accuracy: 0.9812
# Epoch 8/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.0146 - accuracy: 0.9946
# Epoch 9/30
# 12/12 [==============================] - 30s 2s/step - loss: 0.0089 - accuracy: 0.9973
# Epoch 10/30
# 12/12 [==============================] - 31s 2s/step - loss: 0.0116 - accuracy: 0.9919
# Epoch 11/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.0162 - accuracy: 0.9946
# Epoch 12/30
# 12/12 [==============================] - 27s 2s/step - loss: 0.0078 - accuracy: 0.9973
# Epoch 13/30
# 12/12 [==============================] - 26s 2s/step - loss: 0.0148 - accuracy: 0.9946
# Epoch 14/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 15/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 16/30
# 12/12 [==============================] - 28s 2s/step - loss: 3.5520e-04 - accuracy: 1.0000
# Epoch 17/30
# 12/12 [==============================] - 28s 2s/step - loss: 1.3474e-04 - accuracy: 1.0000
# Epoch 18/30
# 12/12 [==============================] - 28s 2s/step - loss: 1.9267e-04 - accuracy: 1.0000
# Epoch 19/30
# 12/12 [==============================] - 26s 2s/step - loss: 3.7891e-05 - accuracy: 1.0000
# Epoch 20/30
# 12/12 [==============================] - 26s 2s/step - loss: 1.9542e-05 - accuracy: 1.0000
# Epoch 21/30
# 12/12 [==============================] - 26s 2s/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 22/30
# 12/12 [==============================] - 26s 2s/step - loss: 0.0021 - accuracy: 0.9973
# Epoch 23/30
# 12/12 [==============================] - 26s 2s/step - loss: 0.0723 - accuracy: 0.9812
# Epoch 24/30
# 12/12 [==============================] - 27s 2s/step - loss: 0.0462 - accuracy: 0.9892
# Epoch 25/30
# 12/12 [==============================] - 27s 2s/step - loss: 0.0366 - accuracy: 0.9812
# Epoch 26/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 27/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.0037 - accuracy: 0.9973
# Epoch 28/30
# 12/12 [==============================] - 33s 3s/step - loss: 0.0591 - accuracy: 0.9866
# Epoch 29/30
# 12/12 [==============================] - 28s 2s/step - loss: 0.0709 - accuracy: 0.9812
# Epoch 30/30
# 12/12 [==============================] - 29s 2s/step - loss: 0.0228 - accuracy: 0.9946

# %%
#Độ chính xác của mô hình 
Score=model.evaluate(training_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 0.012344238348305225
# Train Accuracy 0.9973118305206299

# %%
# Vẽ đồ thị giữa số lần học (Epochs) và độ chính xác (Accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['loss'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train accuracy','Train loss'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Lưu lại dữ liệu sau khi train
model.save("FaceMembersOfClass.h5")

# %%
#Load mô hình đã lưu
model_CNN=load_model('FaceMembersOfClass.h5')

# %%
#Testing
test="/content/drive/MyDrive/AI/FaceMembersOfClass/Test"

for i in os.listdir(test):
  img=load_img(test+'/'+i,target_size=(150,150))
  plt.imshow(img)
  img=img_to_array(img)
  img=img.astype('float32')
  img=img/255
  img=np.expand_dims(img,axis=0)
  
  result = int(np.argmax(model_CNN.predict(img),axis =1))

  class_name=['HoaiPhong','HongMinh','HuuLong','QuangHuy','TrongLuan','TrungHau','VietHa']
  
  print(class_name[result])
  plt.show()
# Out:
# 1/1 [==============================] - 0s 179ms/step
# QuangHuy
# 1/1 [==============================] - 0s 46ms/step
# QuangHuy
# 1/1 [==============================] - 0s 122ms/step
# QuangHuy
# 1/1 [==============================] - 0s 181ms/step
# VietHa
# 1/1 [==============================] - 0s 70ms/step
# VietHa
# 1/1 [==============================] - 0s 168ms/step
# VietHa
# 1/1 [==============================] - 0s 154ms/step
# TrongLuan
# 1/1 [==============================] - 0s 154ms/step
# TrongLuan
# 1/1 [==============================] - 0s 229ms/step
# TrongLuan
# 1/1 [==============================] - 0s 75ms/step
# HongMinh
# 1/1 [==============================] - 0s 75ms/step
# HongMinh
# 1/1 [==============================] - 0s 52ms/step
# HongMinh
# 1/1 [==============================] - 0s 44ms/step
# HoaiPhong
# 1/1 [==============================] - 0s 49ms/step
# HoaiPhong
# 1/1 [==============================] - 0s 45ms/step
# HoaiPhong
# 1/1 [==============================] - 0s 44ms/step
# HuuLong
# 1/1 [==============================] - 0s 47ms/step
# HuuLong
# 1/1 [==============================] - 0s 45ms/step
# TrungHau
# 1/1 [==============================] - 0s 46ms/step
# TrungHau
# 1/1 [==============================] - 0s 47ms/step
# TrungHau
# 1/1 [==============================] - 0s 44ms/step
# HuuLong
